# %%
# !python3 eval_results.py
# Out:
# /root/DIVINE-ML10M/evaluation.py:106: UserWarning: torch.sparse.SparseTensor(indices, values, shape, *, device=) is deprecated.  Please use torch.sparse_coo_tensor(indices, values, shape, dtype=, device=). (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:653.)
#   return t.sparse.FloatTensor(idxs, vals, shape).cuda()
# USER 69878 ITEM 10195
# NUM OF INTERACTIONS 6999171
# eval epoch 0: 100%|█████████████████████| 69878/69878 [00:13<00:00, 5073.71it/s]
# Epoch 0 |	recall@10: 0.09520614516624912	ndcg@10: 0.18610662726363955
# recall@20: 0.16022605635014942	ndcg@20: 0.19552278325332084
# recall@40: 0.25398176469112144	ndcg@40: 0.2209359628456149
# ** best performance: epoch 0 **
# Epoch 0 |	recall@10: 0.09520614516624912	ndcg@10: 0.18610662726363955
# recall@20: 0.16022605635014942	ndcg@20: 0.19552278325332084
# recall@40: 0.25398176469112144	ndcg@40: 0.2209359628456149
# eval epoch 1: 100%|█████████████████████| 69878/69878 [00:13<00:00, 5142.70it/s]
# ...
