# %%
# !python3 eval_results.py
# Out:
# /root/DIVINE-AMAZON/evaluation.py:106: UserWarning: torch.sparse.SparseTensor(indices, values, shape, *, device=) is deprecated.  Please use torch.sparse_coo_tensor(indices, values, shape, dtype=, device=). (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:653.)
#   return t.sparse.FloatTensor(idxs, vals, shape).cuda()
# USER 78578 ITEM 77801
# NUM OF INTERACTIONS 2240156
# eval epoch 0: 100%|██████████████████████| 78578/78578 [01:56<00:00, 673.06it/s]
# Epoch 0 |	recall@10: 0.02756649731762683	ndcg@10: 0.02895303403462971
# recall@20: 0.04269612672547775	ndcg@20: 0.0337694712121783
# recall@40: 0.06455896088785033	ndcg@40: 0.04104839469232385
# ** best performance: epoch 0 **
# Epoch 0 |	recall@10: 0.02756649731762683	ndcg@10: 0.02895303403462971
# recall@20: 0.04269612672547775	ndcg@20: 0.0337694712121783
# recall@40: 0.06455896088785033	ndcg@40: 0.04104839469232385
# eval epoch 1: 100%|██████████████████████| 78578/78578 [01:57<00:00, 669.81it/s]
# ...
