# %%
# !python3 fused.py
# Out:
# /Users/zhangshanfan/Desktop/TMALL-CODE/fig1/fused.py:61: DeprecationWarning: Please import `coo_matrix` from the `scipy.sparse` namespace; the `scipy.sparse.coo` namespace is deprecated and will be removed in SciPy 2.0.0.
#   return pickle.load(f)
# /Users/zhangshanfan/Desktop/TMALL-CODE/fig1/fused.py:61: DeprecationWarning: numpy.core._multiarray_umath is deprecated and has been renamed to numpy._core._multiarray_umath. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core._multiarray_umath._reconstruct.
#   return pickle.load(f)
# Saved:
#   CSV    : analysis_outputs/perspective_dependence_tmall/tmall_perspective_affinity.csv
# ...
