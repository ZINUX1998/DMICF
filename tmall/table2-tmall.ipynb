# %%
# !python3 eval_results.py
# Out:
# /root/DIVINE-验证/evaluation.py:106: UserWarning: torch.sparse.SparseTensor(indices, values, shape, *, device=) is deprecated.  Please use torch.sparse_coo_tensor(indices, values, shape, dtype=, device=). (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:653.)
#   return t.sparse.FloatTensor(idxs, vals, shape).cuda()
# USER 47939 ITEM 41390
# NUM OF INTERACTIONS 2357450
# eval epoch 0: 100%|█████████████████████| 47939/47939 [00:36<00:00, 1319.44it/s]
# Epoch 0 |	recall@10: 0.00959338824095559	ndcg@10: 0.008107821822029746
# recall@20: 0.016476869086508115	ndcg@20: 0.010980693972689137
# recall@40: 0.02797817754245852	ndcg@40: 0.015024437413103671
# ** best performance: epoch 0 **
# Epoch 0 |	recall@10: 0.00959338824095559	ndcg@10: 0.008107821822029746
# recall@20: 0.016476869086508115	ndcg@20: 0.010980693972689137
# recall@40: 0.02797817754245852	ndcg@40: 0.015024437413103671
# eval epoch 1: 100%|█████████████████████| 47939/47939 [00:36<00:00, 1324.31it/s]
# ...
